# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 738

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config1 import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "https://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]       
        city_weather_des = city_weather["weather"][0]["description"]    
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_des})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mareeba
# Processing Record 2 of Set 1 | antofagasta
# Processing Record 3 of Set 1 | port keats
# Processing Record 4 of Set 1 | broome
# Processing Record 5 of Set 1 | butaritari
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | lavrentiya
# Processing Record 8 of Set 1 | val-david
# Processing Record 9 of Set 1 | ribeira grande
# Processing Record 10 of Set 1 | sokolovo-kundryuchenskiy
# Processing Record 11 of Set 1 | kyzyl-suu
# Processing Record 12 of Set 1 | luohe
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | bambous virieux
# Processing Record 15 of Set 1 | hilo
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | zhezkazgan
# Processing Record 19 of Set 1 | narsaq
# Processing Record 20 of Set 1 | quang ngai
# Processing Record 21 of Set 1 | tautira
# Processing Record 22 of Set 1 | san patricio
# Processing Record 23 of Set 1 | pastos bons
# Processing Record 24 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 1 | balkanabat
# Processing Record 27 of Set 1 | talnakh
# Processing Record 28 of Set 1 | hambantota
# Processing Record 29 of Set 1 | kangaatsiaq
# Processing Record 30 of Set 1 | wajima
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | carnarvon
# Processing Record 33 of Set 1 | shyryayeve
# Processing Record 34 of Set 1 | busselton
# Processing Record 35 of Set 1 | torbay
# Processing Record 36 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 37 of Set 1 | khatanga
# Processing Record 38 of Set 1 | chuy
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | yerbogachen
# Processing Record 41 of Set 1 | yumen
# Processing Record 42 of Set 1 | tuktoyaktuk
# Processing Record 43 of Set 1 | kruisfontein
# Processing Record 44 of Set 1 | albany
# Processing Record 45 of Set 1 | christchurch
# Processing Record 46 of Set 1 | lebu
# Processing Record 47 of Set 1 | punta arenas
# Processing Record 48 of Set 1 | camargo
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | mudyuga
# City not found. Skipping...
# Processing Record 1 of Set 2 | kavieng
# Processing Record 2 of Set 2 | loa janan
# Processing Record 3 of Set 2 | bayan
# Processing Record 4 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 5 of Set 2 | souillac
# Processing Record 6 of Set 2 | thompson
# Processing Record 7 of Set 2 | vestmannaeyjar
# Processing Record 8 of Set 2 | tuatapere
# Processing Record 9 of Set 2 | broken hill
# Processing Record 10 of Set 2 | chokurdakh
# Processing Record 11 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | nanortalik
# Processing Record 14 of Set 2 | saint-louis
# Processing Record 15 of Set 2 | mackenzie
# Processing Record 16 of Set 2 | nanning
# Processing Record 17 of Set 2 | mana
# Processing Record 18 of Set 2 | husavik
# Processing Record 19 of Set 2 | aksarka
# Processing Record 20 of Set 2 | ahipara
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | umm kaddadah
# Processing Record 23 of Set 2 | orgovany
# Processing Record 24 of Set 2 | yellowknife
# Processing Record 25 of Set 2 | atuona
# Processing Record 26 of Set 2 | kapaa
# Processing Record 27 of Set 2 | verkhoyansk
# Processing Record 28 of Set 2 | sobolevo
# Processing Record 29 of Set 2 | chapais
# Processing Record 30 of Set 2 | dingle
# Processing Record 31 of Set 2 | vargashi
# Processing Record 32 of Set 2 | olafsvik
# Processing Record 33 of Set 2 | san carlos de bariloche
# Processing Record 34 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 2 | provideniya
# Processing Record 36 of Set 2 | bay roberts
# Processing Record 37 of Set 2 | katsuura
# Processing Record 38 of Set 2 | neuquen
# Processing Record 39 of Set 2 | huainan
# Processing Record 40 of Set 2 | bengkulu
# Processing Record 41 of Set 2 | vardo
# Processing Record 42 of Set 2 | snasa
# Processing Record 43 of Set 2 | kaitangata
# Processing Record 44 of Set 2 | cayenne
# Processing Record 45 of Set 2 | mar del plata
# Processing Record 46 of Set 2 | hithadhoo
# Processing Record 47 of Set 2 | nabire
# Processing Record 48 of Set 2 | khandyga
# Processing Record 49 of Set 2 | east london
# Processing Record 50 of Set 2 | irbil
# Processing Record 1 of Set 3 | nguiu
# City not found. Skipping...
# Processing Record 2 of Set 3 | mehamn
# Processing Record 3 of Set 3 | ust-nera
# Processing Record 4 of Set 3 | hermanus
# Processing Record 5 of Set 3 | flin flon
# Processing Record 6 of Set 3 | klaksvik
# Processing Record 7 of Set 3 | hasaki
# Processing Record 8 of Set 3 | buraydah
# Processing Record 9 of Set 3 | florida
# Processing Record 10 of Set 3 | port-cartier
# Processing Record 11 of Set 3 | starobaltachevo
# Processing Record 12 of Set 3 | saint george
# Processing Record 13 of Set 3 | mataura
# Processing Record 14 of Set 3 | ankpa
# Processing Record 15 of Set 3 | ugoofaaru
# Processing Record 16 of Set 3 | sumbe
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | houston
# Processing Record 19 of Set 3 | lavumisa
# Processing Record 20 of Set 3 | gat
# Processing Record 21 of Set 3 | asau
# Processing Record 22 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 3 | cabo san lucas
# Processing Record 24 of Set 3 | hastings
# Processing Record 25 of Set 3 | sao paulo de olivenca
# Processing Record 26 of Set 3 | kitimat
# Processing Record 27 of Set 3 | qaanaaq
# Processing Record 28 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 29 of Set 3 | avarua
# Processing Record 30 of Set 3 | ilulissat
# Processing Record 31 of Set 3 | lahat
# Processing Record 32 of Set 3 | nikolskoye
# Processing Record 33 of Set 3 | hofn
# Processing Record 34 of Set 3 | bluff
# Processing Record 35 of Set 3 | barrow
# Processing Record 36 of Set 3 | general roca
# Processing Record 37 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 3 | veraval
# Processing Record 39 of Set 3 | russell
# Processing Record 40 of Set 3 | callaway
# Processing Record 41 of Set 3 | tasiilaq
# Processing Record 42 of Set 3 | jamestown
# Processing Record 43 of Set 3 | linxia
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | piterka
# Processing Record 46 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 3 | clyde river
# Processing Record 48 of Set 3 | shache
# Processing Record 49 of Set 3 | luwuk
# Processing Record 50 of Set 3 | am timan
# Processing Record 1 of Set 4 | keetmanshoop
# Processing Record 2 of Set 4 | sayyan
# Processing Record 3 of Set 4 | raudeberg
# Processing Record 4 of Set 4 | esperance
# Processing Record 5 of Set 4 | gravdal
# Processing Record 6 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 4 | caico
# Processing Record 8 of Set 4 | quatre cocos
# Processing Record 9 of Set 4 | talara
# Processing Record 10 of Set 4 | maceio
# Processing Record 11 of Set 4 | amberieu-en-bugey
# Processing Record 12 of Set 4 | norman wells
# Processing Record 13 of Set 4 | plettenberg bay
# Processing Record 14 of Set 4 | arcachon
# Processing Record 15 of Set 4 | san cristobal
# Processing Record 16 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 4 | ulladulla
# Processing Record 18 of Set 4 | xam nua
# Processing Record 19 of Set 4 | port hedland
# Processing Record 20 of Set 4 | bethel
# Processing Record 21 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 22 of Set 4 | pala
# Processing Record 23 of Set 4 | port elizabeth
# Processing Record 24 of Set 4 | skibbereen
# Processing Record 25 of Set 4 | makakilo city
# Processing Record 26 of Set 4 | pisco
# Processing Record 27 of Set 4 | tiksi
# Processing Record 28 of Set 4 | sao jose da coroa grande
# Processing Record 29 of Set 4 | kimbe
# Processing Record 30 of Set 4 | lagoa
# Processing Record 31 of Set 4 | hakkari
# Processing Record 32 of Set 4 | mikumi
# Processing Record 33 of Set 4 | atraulia
# Processing Record 34 of Set 4 | tilichiki
# Processing Record 35 of Set 4 | mahebourg
# Processing Record 36 of Set 4 | camocim
# Processing Record 37 of Set 4 | bubaque
# Processing Record 38 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 39 of Set 4 | kodiak
# Processing Record 40 of Set 4 | alora
# Processing Record 41 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 42 of Set 4 | jacareacanga
# Processing Record 43 of Set 4 | kahului
# Processing Record 44 of Set 4 | naze
# Processing Record 45 of Set 4 | naestved
# Processing Record 46 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 47 of Set 4 | zhigansk
# Processing Record 48 of Set 4 | lander
# Processing Record 49 of Set 4 | borlange
# City not found. Skipping...
# Processing Record 50 of Set 4 | ambon
# Processing Record 1 of Set 5 | port alfred
# Processing Record 2 of Set 5 | salinopolis
# Processing Record 3 of Set 5 | morant bay
# Processing Record 4 of Set 5 | kashan
# Processing Record 5 of Set 5 | miandrivazo
# Processing Record 6 of Set 5 | yulara
# Processing Record 7 of Set 5 | yining
# Processing Record 8 of Set 5 | fort saint john
# City not found. Skipping...
# Processing Record 9 of Set 5 | new norfolk
# Processing Record 10 of Set 5 | saskylakh
# Processing Record 11 of Set 5 | kununurra
# Processing Record 12 of Set 5 | porto novo
# Processing Record 13 of Set 5 | salalah
# Processing Record 14 of Set 5 | santo tomas
# Processing Record 15 of Set 5 | buchanan
# Processing Record 16 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 5 | kitale
# Processing Record 18 of Set 5 | port hueneme
# Processing Record 19 of Set 5 | baykit
# Processing Record 20 of Set 5 | bousso
# Processing Record 21 of Set 5 | walvis bay
# Processing Record 22 of Set 5 | deputatskiy
# Processing Record 23 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 24 of Set 5 | te anau
# Processing Record 25 of Set 5 | lucapa
# Processing Record 26 of Set 5 | porto velho
# Processing Record 27 of Set 5 | kavaratti
# Processing Record 28 of Set 5 | vilhena
# Processing Record 29 of Set 5 | saldanha
# Processing Record 30 of Set 5 | camacha
# Processing Record 31 of Set 5 | airai
# Processing Record 32 of Set 5 | los llanos de aridane
# Processing Record 33 of Set 5 | laguna
# Processing Record 34 of Set 5 | hami
# Processing Record 35 of Set 5 | bandarbeyla
# Processing Record 36 of Set 5 | stephenville crossing
# Processing Record 37 of Set 5 | prainha
# Processing Record 38 of Set 5 | hualmay
# Processing Record 39 of Set 5 | marawi
# Processing Record 40 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 5 | pervomaysk
# Processing Record 42 of Set 5 | swift current
# Processing Record 43 of Set 5 | codrington
# Processing Record 44 of Set 5 | paamiut
# Processing Record 45 of Set 5 | karachev
# Processing Record 46 of Set 5 | saint-joseph
# Processing Record 47 of Set 5 | longyearbyen
# Processing Record 48 of Set 5 | luganville
# Processing Record 49 of Set 5 | cabinda
# Processing Record 50 of Set 5 | goba
# Processing Record 1 of Set 6 | saint-pierre
# Processing Record 2 of Set 6 | iquique
# Processing Record 3 of Set 6 | hammerfest
# Processing Record 4 of Set 6 | labytnangi
# Processing Record 5 of Set 6 | lubango
# Processing Record 6 of Set 6 | constitucion
# Processing Record 7 of Set 6 | port hardy
# Processing Record 8 of Set 6 | coquimbo
# Processing Record 9 of Set 6 | paso de los toros
# Processing Record 10 of Set 6 | perth
# Processing Record 11 of Set 6 | nagato
# Processing Record 12 of Set 6 | margate
# Processing Record 13 of Set 6 | faanui
# Processing Record 14 of Set 6 | rocha
# Processing Record 15 of Set 6 | shumskiy
# Processing Record 16 of Set 6 | luderitz
# Processing Record 17 of Set 6 | polunochnoye
# Processing Record 18 of Set 6 | formoso do araguaia
# City not found. Skipping...
# Processing Record 19 of Set 6 | aklavik
# Processing Record 20 of Set 6 | mogadishu
# Processing Record 21 of Set 6 | mvuma
# Processing Record 22 of Set 6 | yelizovo
# Processing Record 23 of Set 6 | lorengau
# Processing Record 24 of Set 6 | flinders
# Processing Record 25 of Set 6 | horqueta
# Processing Record 26 of Set 6 | thap than
# Processing Record 27 of Set 6 | vila franca do campo
# Processing Record 28 of Set 6 | yar-sale
# Processing Record 29 of Set 6 | saint anthony
# Processing Record 30 of Set 6 | dzhebariki-khaya
# Processing Record 31 of Set 6 | cherskiy
# Processing Record 32 of Set 6 | guerrero negro
# Processing Record 33 of Set 6 | ancud
# Processing Record 34 of Set 6 | ca mau
# Processing Record 35 of Set 6 | suntar
# Processing Record 36 of Set 6 | korla
# Processing Record 37 of Set 6 | yatou
# Processing Record 38 of Set 6 | merritt
# Processing Record 39 of Set 6 | chulman
# Processing Record 40 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 41 of Set 6 | najran
# Processing Record 42 of Set 6 | vung tau
# Processing Record 43 of Set 6 | castro
# Processing Record 44 of Set 6 | vanimo
# Processing Record 45 of Set 6 | upington
# Processing Record 46 of Set 6 | san rafael
# Processing Record 47 of Set 6 | taltal
# Processing Record 48 of Set 6 | lasa
# Processing Record 49 of Set 6 | shujalpur
# Processing Record 50 of Set 6 | tupik
# Processing Record 1 of Set 7 | guilin
# Processing Record 2 of Set 7 | sola
# Processing Record 3 of Set 7 | cidreira
# Processing Record 4 of Set 7 | inuvik
# Processing Record 5 of Set 7 | ola
# Processing Record 6 of Set 7 | caravelas
# Processing Record 7 of Set 7 | magnitka
# Processing Record 8 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 7 | westport
# Processing Record 10 of Set 7 | garden city
# Processing Record 11 of Set 7 | nuevo progreso
# Processing Record 12 of Set 7 | portland
# Processing Record 13 of Set 7 | college
# Processing Record 14 of Set 7 | hamilton
# Processing Record 15 of Set 7 | axim
# Processing Record 16 of Set 7 | mitsamiouli
# Processing Record 17 of Set 7 | ponta do sol
# Processing Record 18 of Set 7 | moree
# Processing Record 19 of Set 7 | tangjiazhuang
# Processing Record 20 of Set 7 | magam
# Processing Record 21 of Set 7 | ayan
# Processing Record 22 of Set 7 | lompoc
# Processing Record 23 of Set 7 | sao joao da barra
# Processing Record 24 of Set 7 | harper
# Processing Record 25 of Set 7 | la ronge
# Processing Record 26 of Set 7 | colares
# Processing Record 27 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 28 of Set 7 | santarem
# Processing Record 29 of Set 7 | mullaitivu
# City not found. Skipping...
# Processing Record 30 of Set 7 | bairiki
# Processing Record 31 of Set 7 | fortuna
# Processing Record 32 of Set 7 | jalu
# Processing Record 33 of Set 7 | grindavik
# Processing Record 34 of Set 7 | karauzyak
# City not found. Skipping...
# Processing Record 35 of Set 7 | morgan city
# Processing Record 36 of Set 7 | dunedin
# Processing Record 37 of Set 7 | saint-philippe
# Processing Record 38 of Set 7 | grand gaube
# Processing Record 39 of Set 7 | meulaboh
# Processing Record 40 of Set 7 | ulaanbaatar
# Processing Record 41 of Set 7 | la asuncion
# Processing Record 42 of Set 7 | fairbanks
# Processing Record 43 of Set 7 | pozo colorado
# Processing Record 44 of Set 7 | blythe
# Processing Record 45 of Set 7 | aripuana
# Processing Record 46 of Set 7 | ban nahin
# Processing Record 47 of Set 7 | abonnema
# Processing Record 48 of Set 7 | kieta
# Processing Record 49 of Set 7 | tazovskiy
# Processing Record 50 of Set 7 | okha
# Processing Record 1 of Set 8 | beruwala
# Processing Record 2 of Set 8 | utrecht
# Processing Record 3 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 4 of Set 8 | tombouctou
# Processing Record 5 of Set 8 | arkhangelskoye
# Processing Record 6 of Set 8 | mackay
# Processing Record 7 of Set 8 | moron de la frontera
# Processing Record 8 of Set 8 | agirish
# Processing Record 9 of Set 8 | tambo grande
# Processing Record 10 of Set 8 | aksum
# Processing Record 11 of Set 8 | paita
# Processing Record 12 of Set 8 | orlik
# Processing Record 13 of Set 8 | mount isa
# Processing Record 14 of Set 8 | opobo
# City not found. Skipping...
# Processing Record 15 of Set 8 | maraba
# Processing Record 16 of Set 8 | altamirano
# Processing Record 17 of Set 8 | banes
# Processing Record 18 of Set 8 | honningsvag
# Processing Record 19 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 8 | dengzhou
# Processing Record 21 of Set 8 | comodoro rivadavia
# Processing Record 22 of Set 8 | varhaug
# Processing Record 23 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 24 of Set 8 | sexsmith
# Processing Record 25 of Set 8 | tougue
# Processing Record 26 of Set 8 | tirano
# Processing Record 27 of Set 8 | port lincoln
# Processing Record 28 of Set 8 | tadine
# Processing Record 29 of Set 8 | kargasok
# Processing Record 30 of Set 8 | soyo
# Processing Record 31 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 32 of Set 8 | norwich
# Processing Record 33 of Set 8 | tezu
# Processing Record 34 of Set 8 | port townsend
# Processing Record 35 of Set 8 | gazli
# Processing Record 36 of Set 8 | ust-kuyga
# Processing Record 37 of Set 8 | lotoshino
# Processing Record 38 of Set 8 | iskateley
# Processing Record 39 of Set 8 | nome
# Processing Record 40 of Set 8 | karasjok
# Processing Record 41 of Set 8 | babu
# Processing Record 42 of Set 8 | ihosy
# Processing Record 43 of Set 8 | dera din panah
# City not found. Skipping...
# Processing Record 44 of Set 8 | pochutla
# Processing Record 45 of Set 8 | leningradskiy
# Processing Record 46 of Set 8 | malaya serdoba
# Processing Record 47 of Set 8 | puerto madero
# Processing Record 48 of Set 8 | hailey
# Processing Record 49 of Set 8 | wejherowo
# Processing Record 50 of Set 8 | lovington
# Processing Record 1 of Set 9 | ostrovnoy
# Processing Record 2 of Set 9 | sao gabriel da cachoeira
# Processing Record 3 of Set 9 | itarema
# Processing Record 4 of Set 9 | horsham
# Processing Record 5 of Set 9 | ambilobe
# Processing Record 6 of Set 9 | deniliquin
# Processing Record 7 of Set 9 | naron
# Processing Record 8 of Set 9 | beringovskiy
# Processing Record 9 of Set 9 | foumban
# Processing Record 10 of Set 9 | carutapera
# Processing Record 11 of Set 9 | aswan
# Processing Record 12 of Set 9 | garissa
# Processing Record 13 of Set 9 | sinnamary
# Processing Record 14 of Set 9 | mayo
# Processing Record 15 of Set 9 | samarai
# Processing Record 16 of Set 9 | cascais
# Processing Record 17 of Set 9 | chaihe
# Processing Record 18 of Set 9 | touros
# Processing Record 19 of Set 9 | havoysund
# Processing Record 20 of Set 9 | lata
# Processing Record 21 of Set 9 | almeirim
# Processing Record 22 of Set 9 | chaumont
# Processing Record 23 of Set 9 | del rio
# Processing Record 24 of Set 9 | isangel
# Processing Record 25 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 26 of Set 9 | terme
# Processing Record 27 of Set 9 | pringsewu
# Processing Record 28 of Set 9 | bonthe
# Processing Record 29 of Set 9 | vanavara
# Processing Record 30 of Set 9 | mahajanga
# Processing Record 31 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 33 of Set 9 | evanston
# Processing Record 34 of Set 9 | mahibadhoo
# Processing Record 35 of Set 9 | el alto
# Processing Record 36 of Set 9 | fare
# Processing Record 37 of Set 9 | bathsheba
# Processing Record 38 of Set 9 | plyussa
# Processing Record 39 of Set 9 | kilindoni
# Processing Record 40 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 41 of Set 9 | little current
# Processing Record 42 of Set 9 | inhambane
# Processing Record 43 of Set 9 | victoria
# Processing Record 44 of Set 9 | colchester
# Processing Record 45 of Set 9 | kapoeta
# Processing Record 46 of Set 9 | chumikan
# Processing Record 47 of Set 9 | mattru
# Processing Record 48 of Set 9 | turhal
# Processing Record 49 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 50 of Set 9 | yilan
# Processing Record 1 of Set 10 | tongliao
# Processing Record 2 of Set 10 | khasan
# Processing Record 3 of Set 10 | curuca
# Processing Record 4 of Set 10 | abadan
# Processing Record 5 of Set 10 | srednekolymsk
# Processing Record 6 of Set 10 | coihaique
# Processing Record 7 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 10 | berdigestyakh
# Processing Record 9 of Set 10 | havre-saint-pierre
# Processing Record 10 of Set 10 | ogdensburg
# Processing Record 11 of Set 10 | santa cruz
# Processing Record 12 of Set 10 | inirida
# Processing Record 13 of Set 10 | pevek
# Processing Record 14 of Set 10 | diamantino
# Processing Record 15 of Set 10 | caconda
# Processing Record 16 of Set 10 | dalby
# Processing Record 17 of Set 10 | bowen
# Processing Record 18 of Set 10 | saint-francois
# Processing Record 19 of Set 10 | huangnihe
# Processing Record 20 of Set 10 | kendari
# Processing Record 21 of Set 10 | benjamin aceval
# Processing Record 22 of Set 10 | wiset chai chan
# Processing Record 23 of Set 10 | biak
# Processing Record 24 of Set 10 | amuntai
# Processing Record 25 of Set 10 | zyryanovsk
# Processing Record 26 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 27 of Set 10 | shasta lake
# Processing Record 28 of Set 10 | chengde
# Processing Record 29 of Set 10 | geresk
# City not found. Skipping...
# Processing Record 30 of Set 10 | tlacote el bajo
# Processing Record 31 of Set 10 | doka
# Processing Record 32 of Set 10 | salvador
# Processing Record 33 of Set 10 | takoradi
# Processing Record 34 of Set 10 | kumluca
# Processing Record 35 of Set 10 | surin
# Processing Record 36 of Set 10 | sioux lookout
# Processing Record 37 of Set 10 | udimskiy
# Processing Record 38 of Set 10 | severo-kurilsk
# Processing Record 39 of Set 10 | mount gambier
# Processing Record 40 of Set 10 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 10 | highland
# Processing Record 42 of Set 10 | high level
# Processing Record 43 of Set 10 | kysyl-syr
# Processing Record 44 of Set 10 | atherton
# Processing Record 45 of Set 10 | xuddur
# Processing Record 46 of Set 10 | matamoros
# Processing Record 47 of Set 10 | payakumbuh
# Processing Record 48 of Set 10 | cilegon
# Processing Record 49 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 50 of Set 10 | panaba
# Processing Record 1 of Set 11 | mudgee
# Processing Record 2 of Set 11 | sao filipe
# Processing Record 3 of Set 11 | abnub
# Processing Record 4 of Set 11 | boguchany
# Processing Record 5 of Set 11 | victor harbor
# Processing Record 6 of Set 11 | presidencia roque saenz pena
# Processing Record 7 of Set 11 | orocue
# Processing Record 8 of Set 11 | longyan
# Processing Record 9 of Set 11 | matara
# Processing Record 10 of Set 11 | dodola
# Processing Record 11 of Set 11 | tune
# Processing Record 12 of Set 11 | atbasar
# Processing Record 13 of Set 11 | centralia
# Processing Record 14 of Set 11 | nantucket
# Processing Record 15 of Set 11 | tidore
# City not found. Skipping...
# Processing Record 16 of Set 11 | edd
# Processing Record 17 of Set 11 | kotri
# Processing Record 18 of Set 11 | half moon bay
# Processing Record 19 of Set 11 | witu
# Processing Record 20 of Set 11 | cururupu
# Processing Record 21 of Set 11 | kuruman
# Processing Record 22 of Set 11 | trincomalee
# Processing Record 23 of Set 11 | petrozavodsk
# Processing Record 24 of Set 11 | vaitape
# Processing Record 25 of Set 11 | tubarao
# Processing Record 26 of Set 11 | pacific grove
# Processing Record 27 of Set 11 | mancio lima
# Processing Record 28 of Set 11 | maine-soroa
# Processing Record 29 of Set 11 | adrar
# Processing Record 30 of Set 11 | bokspits
# City not found. Skipping...
# Processing Record 31 of Set 11 | sampit
# Processing Record 32 of Set 11 | lahaina
# Processing Record 33 of Set 11 | capreol
# Processing Record 34 of Set 11 | asfi
# Processing Record 35 of Set 11 | sitka
# Processing Record 36 of Set 11 | alta floresta
# Processing Record 37 of Set 11 | poum
# Processing Record 38 of Set 11 | tanout
# Processing Record 39 of Set 11 | bambanglipuro
# Processing Record 40 of Set 11 | necochea
# Processing Record 41 of Set 11 | dori
# Processing Record 42 of Set 11 | chernyshevskiy
# Processing Record 43 of Set 11 | cabra
# Processing Record 44 of Set 11 | adre
# Processing Record 45 of Set 11 | belaya gora
# Processing Record 46 of Set 11 | macapa
# Processing Record 47 of Set 11 | noumea
# Processing Record 48 of Set 11 | oranjemund
# Processing Record 49 of Set 11 | zemio
# Processing Record 50 of Set 11 | poli
# Processing Record 1 of Set 12 | rorvik
# Processing Record 2 of Set 12 | dubbo
# Processing Record 3 of Set 12 | sulz
# Processing Record 4 of Set 12 | westerland
# Processing Record 5 of Set 12 | porto torres
# Processing Record 6 of Set 12 | tingrela
# City not found. Skipping...
# Processing Record 7 of Set 12 | estelle
# Processing Record 8 of Set 12 | brae
# Processing Record 9 of Set 12 | hovd
# Processing Record 10 of Set 12 | netivot
# Processing Record 11 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 12 | sur
# Processing Record 13 of Set 12 | byron bay
# Processing Record 14 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 15 of Set 12 | padang
# Processing Record 16 of Set 12 | shemonaikha
# Processing Record 17 of Set 12 | umm lajj
# Processing Record 18 of Set 12 | tura
# Processing Record 19 of Set 12 | nelson bay
# Processing Record 20 of Set 12 | ushtobe
# Processing Record 21 of Set 12 | krasnyy profintern
# Processing Record 22 of Set 12 | laurel
# Processing Record 23 of Set 12 | novikovo
# Processing Record 24 of Set 12 | balimo
# City not found. Skipping...
# Processing Record 25 of Set 12 | santa rosa
# Processing Record 26 of Set 12 | bengbu
# Processing Record 27 of Set 12 | palmer
# Processing Record 28 of Set 12 | krasnyy chikoy
# Processing Record 29 of Set 12 | atar
# Processing Record 30 of Set 12 | puri
# Processing Record 31 of Set 12 | port blair
# Processing Record 32 of Set 12 | lanat
# Processing Record 33 of Set 12 | kaeo
# Processing Record 34 of Set 12 | hachinohe
# Processing Record 35 of Set 12 | karasburg
# Processing Record 36 of Set 12 | kenai
# Processing Record 37 of Set 12 | rio branco
# Processing Record 38 of Set 12 | labuan
# Processing Record 39 of Set 12 | xique-xique
# Processing Record 40 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 41 of Set 12 | dosso
# Processing Record 42 of Set 12 | barranca
# Processing Record 43 of Set 12 | macau
# Processing Record 44 of Set 12 | belmonte
# Processing Record 45 of Set 12 | eatonton
# Processing Record 46 of Set 12 | novobeysugskaya
# Processing Record 47 of Set 12 | port macquarie
# Processing Record 48 of Set 12 | juifang
# City not found. Skipping...
# Processing Record 49 of Set 12 | puerto madryn
# Processing Record 50 of Set 12 | iqaluit
# Processing Record 1 of Set 13 | ambodifototra
# City not found. Skipping...
# Processing Record 2 of Set 13 | alekseyevsk
# Processing Record 3 of Set 13 | zonguldak
# Processing Record 4 of Set 13 | areosa
# Processing Record 5 of Set 13 | nyurba
# Processing Record 6 of Set 13 | awjilah
# Processing Record 7 of Set 13 | yaan
# Processing Record 8 of Set 13 | santa maria
# Processing Record 9 of Set 13 | magui
# City not found. Skipping...
# Processing Record 10 of Set 13 | shahrud
# Processing Record 11 of Set 13 | ust-tarka
# Processing Record 12 of Set 13 | dapaong
# Processing Record 13 of Set 13 | brokopondo
# Processing Record 14 of Set 13 | fianarantsoa
# Processing Record 15 of Set 13 | doha
# Processing Record 16 of Set 13 | phalaborwa
# Processing Record 17 of Set 13 | maragogi
# Processing Record 18 of Set 13 | forestville
# Processing Record 19 of Set 13 | creel
# Processing Record 20 of Set 13 | mugumu
# Processing Record 21 of Set 13 | ballina
# Processing Record 22 of Set 13 | mongo
# Processing Record 23 of Set 13 | taoudenni
# Processing Record 24 of Set 13 | itaituba
# Processing Record 25 of Set 13 | muscat
# Processing Record 26 of Set 13 | iranshahr
# Processing Record 27 of Set 13 | yingcheng
# Processing Record 28 of Set 13 | ust-koksa
# Processing Record 29 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 13 | vao
# Processing Record 31 of Set 13 | lerwick
# Processing Record 32 of Set 13 | martin
# Processing Record 33 of Set 13 | geraldton
# Processing Record 34 of Set 13 | kindersley
# Processing Record 35 of Set 13 | turan
# Processing Record 36 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 37 of Set 13 | pangnirtung
# Processing Record 38 of Set 13 | talaya
# Processing Record 39 of Set 13 | shingu
# Processing Record 40 of Set 13 | tirat karmel
# Processing Record 41 of Set 13 | palu
# Processing Record 42 of Set 13 | ruston
# Processing Record 43 of Set 13 | la libertad
# Processing Record 44 of Set 13 | colwyn bay
# Processing Record 45 of Set 13 | shiojiri
# Processing Record 46 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 47 of Set 13 | labuhan
# Processing Record 48 of Set 13 | mocuba
# Processing Record 49 of Set 13 | monrovia
# Processing Record 50 of Set 13 | codajas
# Processing Record 1 of Set 14 | maymanak
# City not found. Skipping...
# Processing Record 2 of Set 14 | staroshcherbinovskaya
# Processing Record 3 of Set 14 | gurupa
# Processing Record 4 of Set 14 | lake city
# Processing Record 5 of Set 14 | escanaba
# Processing Record 6 of Set 14 | sepuka
# Processing Record 7 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 8 of Set 14 | champerico
# Processing Record 9 of Set 14 | dawei
# Processing Record 10 of Set 14 | ust-barguzin
# Processing Record 11 of Set 14 | kinarut
# Processing Record 12 of Set 14 | jharsuguda
# Processing Record 13 of Set 14 | assens
# Processing Record 14 of Set 14 | dasoguz
# Processing Record 15 of Set 14 | darhan
# Processing Record 16 of Set 14 | awbari
# Processing Record 17 of Set 14 | nador
# Processing Record 18 of Set 14 | desesti
# Processing Record 19 of Set 14 | salta
# Processing Record 20 of Set 14 | ayagoz
# Processing Record 21 of Set 14 | kismayo
# Processing Record 22 of Set 14 | burica
# City not found. Skipping...
# Processing Record 23 of Set 14 | alofi
# Processing Record 24 of Set 14 | ojinaga
# Processing Record 25 of Set 14 | wukari
# Processing Record 26 of Set 14 | andenes
# Processing Record 27 of Set 14 | vogar
# Processing Record 28 of Set 14 | ziyamet
# City not found. Skipping...
# Processing Record 29 of Set 14 | ixtapa
# Processing Record 30 of Set 14 | marmora
# Processing Record 31 of Set 14 | tutoia
# Processing Record 32 of Set 14 | dhidhdhoo
# Processing Record 33 of Set 14 | avera
# Processing Record 34 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 35 of Set 14 | igarka
# Processing Record 36 of Set 14 | sarangani
# Processing Record 37 of Set 14 | angoche
# Processing Record 38 of Set 14 | tual
# Processing Record 39 of Set 14 | reconquista
# Processing Record 40 of Set 14 | coos bay
# Processing Record 41 of Set 14 | sabzevar
# Processing Record 42 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 43 of Set 14 | colac
# Processing Record 44 of Set 14 | mehran
# Processing Record 45 of Set 14 | naranjal
# Processing Record 46 of Set 14 | muzquiz
# City not found. Skipping...
# Processing Record 47 of Set 14 | fort nelson
# Processing Record 48 of Set 14 | waingapu
# Processing Record 49 of Set 14 | lebanon
# Processing Record 50 of Set 14 | sept-iles
# Processing Record 1 of Set 15 | sao miguel do araguaia
# Processing Record 2 of Set 15 | ucluelet
# Processing Record 3 of Set 15 | ribnitz-damgarten
# Processing Record 4 of Set 15 | hazorasp
# Processing Record 5 of Set 15 | payo
# Processing Record 6 of Set 15 | ovsyanka
# Processing Record 7 of Set 15 | haines junction
# Processing Record 8 of Set 15 | vilyuysk
# Processing Record 9 of Set 15 | manokwari
# Processing Record 10 of Set 15 | san quintin
# Processing Record 11 of Set 15 | biltine
# Processing Record 12 of Set 15 | seoul
# Processing Record 13 of Set 15 | mastic beach
# Processing Record 14 of Set 15 | sorland
# Processing Record 15 of Set 15 | yertsevo
# Processing Record 16 of Set 15 | qrendi
# Processing Record 17 of Set 15 | svetlyy
# Processing Record 18 of Set 15 | locharbriggs
# Processing Record 19 of Set 15 | asosa
# Processing Record 20 of Set 15 | teguise
# Processing Record 21 of Set 15 | taveta
# Processing Record 22 of Set 15 | juchitlan
# Processing Record 23 of Set 15 | lethem
# Processing Record 24 of Set 15 | wyndham
# Processing Record 25 of Set 15 | santa ana
# Processing Record 26 of Set 15 | riyadh
# Processing Record 27 of Set 15 | marystown
# Processing Record 28 of Set 15 | berlevag
# Processing Record 29 of Set 15 | ozinki
# Processing Record 30 of Set 15 | tefe
# Processing Record 31 of Set 15 | pontianak
# Processing Record 32 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 33 of Set 15 | ketchikan
# Processing Record 34 of Set 15 | kawalu
# Processing Record 35 of Set 15 | garwolin
# Processing Record 36 of Set 15 | dwarka
# Processing Record 37 of Set 15 | derzhavinsk
# Processing Record 38 of Set 15 | tawkar
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 672

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0                   Mareeba -17.0000  145.4333     81.45        83
# 1               Antofagasta -23.6500  -70.4000     58.28        75
# 2                Port Keats -14.2500  129.5500     91.15        53
# 3                    Broome  42.2506  -75.8330     41.85        84
# 4                Butaritari   3.0707  172.7902     82.15        72
# 5                   Ushuaia -54.8000  -68.3000     35.26        75
# 6                Lavrentiya  65.5833 -171.0000     35.80        96
# 7                 Val-David  46.0334  -74.2159     40.01        95
# 8            Ribeira Grande  38.5167  -28.7000     62.78        77
# 9  Sokolovo-Kundryuchenskiy  47.8354   39.9471     51.15        81
#
#    Cloudiness  Wind Speed Country Current Description
# 0          77        7.61      AU          light rain
# 1           8        4.63      CL           clear sky
# 2          89        8.03      AU     overcast clouds
# 3          40        8.05      US    scattered clouds
# 4           9       11.16      KI           clear sky
# 5           0       11.50      AR           clear sky
# 6         100       20.09      RU          light rain
# 7         100        8.77      CA     overcast clouds
# 8          20        4.00      PT          few clouds
# 9         100        2.51      RU          light rain

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#                        City Country      Lat       Lng  Max Temp  Humidity  \
# 0                   Mareeba      AU -17.0000  145.4333     81.45        83
# 1               Antofagasta      CL -23.6500  -70.4000     58.28        75
# 2                Port Keats      AU -14.2500  129.5500     91.15        53
# 3                    Broome      US  42.2506  -75.8330     41.85        84
# 4                Butaritari      KI   3.0707  172.7902     82.15        72
# 5                   Ushuaia      AR -54.8000  -68.3000     35.26        75
# 6                Lavrentiya      RU  65.5833 -171.0000     35.80        96
# 7                 Val-David      CA  46.0334  -74.2159     40.01        95
# 8            Ribeira Grande      PT  38.5167  -28.7000     62.78        77
# 9  Sokolovo-Kundryuchenskiy      RU  47.8354   39.9471     51.15        81
#
#    Cloudiness  Wind Speed Current Description
# 0          77        7.61          light rain
# 1           8        4.63           clear sky
# 2          89        8.03     overcast clouds
# 3          40        8.05    scattered clouds
# 4           9       11.16           clear sky
# 5           0       11.50           clear sky
# 6         100       20.09          light rain
# 7         100        8.77     overcast clouds
# 8          20        4.00          few clouds
# 9         100        2.51          light rain

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
